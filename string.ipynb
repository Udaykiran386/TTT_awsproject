# %% [markdown]
# String : group by words or characters using ' ', " ",""" """

# %%
str1='Hello, picacho!'
print(type(str1))
# Out:
# <class 'str'>

# %%
a = 10
print(type(str(a)))
# Out:
# <class 'str'>

# %%
print(len(str1))  # 13
# Out:
# 15

# %%
str2 = "hello my name is uday this is my pet"
print(str2.count('is'))
# Out:
# 3

# %%
str3 = 'hello my name is uday this is pet'
print(str3.replace('pet',"picacho"))
# Out:
# hello my name is uday this is picacho

# %%
print(str2+" "+str3)
# Out:
# hello my name is uday this is my pet hello my name is uday this is pet

# %%
name='picacho'
power_type='Electric'
print(f"My name is {name} and  {power_type} type pokemon")
# Out:
# My name is picacho and  Electric type pokemon

# %%
str4='My name is picacho and Electric type pokemon'
print(str4.split(" "))
# Out:
# ['My', 'name', 'is', 'picacho', 'and', 'Electric', 'type', 'pokemon']

# %%
name = 'picacho'
print(name*4)
# Out:
# picachopicachopicachopicacho

# %%
str5='picacho Electric Web attack'
  #   012345679012345678901234567
print(str5[0:7])
        #  [start:stop]
print(str5[0:10:2])
        # [start:stop:step]
# Out:
# picacho
# pccoE

# %%
str6 = "##picacho thunder bolt attack##"
print(str6.lstrip('#'))
print(str6.rstrip('#'))
print(str6.strip('#'))
# Out:
# picacho thunder bolt attack##
# ##picacho thunder bolt attack
# picacho thunder bolt attack

# %%
str7="picachO dodge"
print(str7.capitalize())
print(str7.lower())
print(str7.upper())
# Out:
# Picacho dodge
# picacho dodge
# PICACHO DODGE

# %%
str8= "bulbasaur"
print(str8.startswith('bu'))
print(str8.startswith('lb'))

print(str8.endswith("ur"))
print(str8.endswith("sa"))
# Out:
# True
# False
# True
# False

# %%
str8= "bulbasaur"
print(str8 in 'bulbasaur')
print(str8.find('ul'))
# Out:
# True
# 1

# %%
str8= "bulbasaur"
print(str8.isalpha())
print(str8.isnumeric())

str9="100"
print(str9.isalpha())
print(str9.isnumeric())
# Out:
# True
# False
# False
# True

# %%
my_tup = ()
print(type(my_tup))
# Out:
# <class 'tuple'>
